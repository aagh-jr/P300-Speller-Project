# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mne

# %% [markdown]
# Data:

# %%
fname = 'data/train/Data_S02_Sess01.csv'

# %%
misc_ixs = [i for i in range(56, 113)] # i for all i in the range from 32 to 112 inclusive

raw = mne.io.read_raw_edf(fname, misc = misc_ixs, stim_channel = 113, preload = True)

# %%
rename_channel_dict = {}
for ix, ch in enumerate(raw.ch_names):
    if ix >= 56:
        break

    rename_channel_dict[ch] = ch.split('_')[1] # Get rid of 'EEG_'

# Manually rename FP1 and FP2 to Fp1 and Fp2
raw.rename_channels(rename_channel_dict)

    rename_channel_dict[ch] = ch.split('_')[1]  # e.g., 'EEG_Fp1' -> 'Fp1'

raw.rename_channels(rename_channel_dict)

# Apply the standard 10–20 montage
montage = mne.channels.make_standard_montage('standard_1020')
raw.set_montage(montage, match_case=False, on_missing='ignore')
